# %%
import pandas as pd

# %%
# !pip install openpyxl
# Out:
# WARNING: Ignoring invalid distribution -umpy (c:\users\akaga\python_for_classes\env_for_ml_st\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\akaga\python_for_classes\env_for_ml_st\lib\site-packages)
# ...
#      -------------------------------------- 250.0/250.0 kB 1.9 MB/s eta 0:00:00
# ...
# WARNING: Ignoring invalid distribution -umpy (c:\users\akaga\python_for_classes\env_for_ml_st\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\akaga\python_for_classes\env_for_ml_st\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\akaga\python_for_classes\env_for_ml_st\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\akaga\python_for_classes\env_for_ml_st\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\akaga\python_for_classes\env_for_ml_st\lib\site-packages)
# ...

# %%
df = pd.read_excel('data/Raw data/raw2.xlsx')

# %%
df.head()
# Out:
#        PMID       PMC ID                                              Title  \
# 0  36999796          NaN  Strategies to improve access to physical activ...
# 1  36999644          NaN  Excellence in Total Worker Health(R) and an In...
# 2  36999593  PMC10544284  Comparison of Computed Tomography-Based Artifi...
# 3  36999575          NaN  Dermatopathology - Current status and developm...
# 4  36999232          NaN  Data-Driven Prediction of Janus/Core-Shell Mor...
#
#                                            Author(s)  \
# 0  Herbison JD||Osborne M||Andersen J||Lepage P||...
# 1                                           Terry PE
# 2  Eroglu O||Eroglu Y||Yildirim M||Karlidag T||Ci...
# 3                           Mitteldorf C||Tronnier M
# 4           Esteki B||Masoomi M||Moosazadeh M||Yoo C
#
#                                  Author(s) Full Name  \
# 0  Herbison, Jordan D||Osborne, Meaghan||Andersen...
# 1                                      Terry, Paul E
# ...

# %%
df['Source']
# Out:
# 0       Transl Behav Med. 2023 Jul 1;13(7):486-500. do...
# 1       Am J Health Promot. 2023 Jun;37(5):595-601. do...
# 2       J Int Adv Otol. 2023 Jul;19(4):342-349. doi: 1...
# 3       J Dtsch Dermatol Ges. 2023 Apr;21(4):393-397. ...
# 4       Langmuir. 2023 Apr 11;39(14):4943-4958. doi: 1...
#                               ...
# 9994    Front Neurorobot. 2022 Jun 21;16:897110. doi: ...
# 9995    Data Brief. 2022 Jun 17;43:108382. doi: 10.101...
# 9996    Comput Math Methods Med. 2022 Jun 28;2022:8040...
# 9997    Comput Math Methods Med. 2022 Jun 28;2022:8123...
# 9998    Ann Nucl Med. 2022 Aug;36(8):765-776. doi: 10....
# Name: Source, Length: 9999, dtype: object

# %%
import os
import pandas as pd

# Directory containing your .xlsx files
directory_path = 'data/Raw data'

# Output CSV file path
# os.mkdir('data/New Master')
output_csv_path = 'data/New Master/created_new_master_sheet_more_columns.csv'

# Initialize an empty DataFrame to store the extracted data
result_df = pd.DataFrame(columns=['PMID', 'Title', 'Abstract', 'Author(s)', 'Source'])

# Loop through each file in the directory
for filename in os.listdir(directory_path):
    if filename.endswith(".xlsx"):
        file_path = os.path.join(directory_path, filename)

        # Read the Excel file into a DataFrame
        df = pd.read_excel(file_path)

        # Extract relevant columns ('PMID', 'Title', 'Abstract') and append to the result DataFrame
        result_df = result_df.append(df[['PMID', 'Title', 'Abstract', 'Source', 'Author(s)']], ignore_index=True)

# Write the result DataFrame to a single CSV file
result_df.to_csv(output_csv_path, index=False)

print(f"Data extracted and saved to {output_csv_path}")
# Out:
# C:\Users\akaga\AppData\Local\Temp/ipykernel_29884/262743226.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append(df[['PMID', 'Title', 'Abstract', 'Source', 'Author(s)']], ignore_index=True)
# C:\Users\akaga\AppData\Local\Temp/ipykernel_29884/262743226.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append(df[['PMID', 'Title', 'Abstract', 'Source', 'Author(s)']], ignore_index=True)
# C:\Users\akaga\AppData\Local\Temp/ipykernel_29884/262743226.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append(df[['PMID', 'Title', 'Abstract', 'Source', 'Author(s)']], ignore_index=True)
# ...

# %%
result_df.head()
# Out:
#        PMID                                              Title  \
# 0  37982991  Efficacy and Safety of Methylphenidate and Ato...
# 1  37982957  Trait emotional intelligence and resilience: g...
# 2  37982736  Exploring the feasibility of an artificial int...
# 3  37982681  Deep learning-based NT-proBNP prediction from ...
# 4  37982677  Artificial Intelligence Versus Expert Plastic ...
#
#                                             Abstract  \
# 0  BACKGROUND AND OBJECTIVE: Methylphenidate (MPH...
# 1  BACKGROUND: Previous studies have reported str...
# 2  Objective: Skin examination to detect cutaneou...
# 3  OBJECTIVES: The biomarker N-terminal pro B-typ...
# 4  Introduction: Large language models, such as C...
#
#                                            Author(s)  \
# 0  Zhang Y||Yin L||You C||Liu C||Dong P||Xu X||Zh...
# 1  Sojer P||Kainbacher S||Hufner K||Kemmler G||De...
# 2     Helenason J||Ekstrom C||Falk M||Papachristou P
# ...

# %%
import re
text = result_df['Source'][100]
match_part = re.search(r'doi: (.+)', text)
match_part.group(0)
# Out:
# 'doi: 10.1016/j.tics.2023.10.002.'

# %%
match = re.search(r'doi: (.+)', text)

if match:
    substring = match.group(0)
    print(substring)
else:
    print("Substring not found.")
